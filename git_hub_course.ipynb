# %%
git#git
#git clone pour cloner un dépôt Git
# git add pour ajouter des fichiers à l'index
# gitcommit -m "message" pour valider les modifications avec un message
# git push pour envoyer les modifications vers le dépôt distant
# git pull pour récupérer les modifications depuis le dépôt distant
