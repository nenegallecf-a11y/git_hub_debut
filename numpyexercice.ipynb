# %%
import numpy as np;
Rf = 0.02
Rm = 0.08
beta = 1.3

expected_return = Rf + beta * (Rm - Rf)
print(f"Rendement espéré de l’actif : {expected_return*100:.2f}%")
# Out:
# Rendement espéré de l’actif : 9.80%
