# %% [markdown]
# **Attention**: Afin de pouvoir exécuter ce code vous devez mettre le fichier ipynb et le fichier "sp500_prices.csv" dans le même dossier.
#
# Vous disposez d'un DataFrame avec les prix des actions 469 sociétés du SP 500 de 2016 à 2025 (cf code pour télécharger les données avec yfinance). Supposez qu'il existe un actif sans risque au rendement **annuel** de 1%.
# 1) Calculer le rendement annuel moyen de chaque titre ainsi que la matrice de variance covariance. (Indication: il va falloir déterminer le nombre de jours afin d'annualiser les rendements et les écarts types).
# 2) Quel actif est le plus risqué sur la période (a l'écart-type le plus élevé) ? Quel actif possède le plus haut rendement ?
# 3) Déterminer le portefeuille optimal du SP500.
# 4) Tracer la capital market line.

# %%
import pandas as pd
sp500=pd.read_csv('sp500_prices.csv',index_col=0,parse_dates=True)
